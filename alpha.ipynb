# %%
import numpy as np
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta
import warnings
import time
warnings.filterwarnings('ignore')

def get_market_return(period_start, period_end, max_retries=3):
    """
    Get S&P 500 return for a given period with retry logic
    """
    for attempt in range(max_retries):
        try:
            # Convert dates to string format
            start_str = period_start.strftime('%Y-%m-%d')
            end_str = (period_end + timedelta(days=1)).strftime('%Y-%m-%d')

            # Download with explicit parameters
            sp500 = yf.Ticker('^GSPC')
            hist = sp500.history(start=start_str, end=end_str, auto_adjust=True)

            if not hist.empty and len(hist) >= 2:
                # Use Close prices instead of Adj Close
                start_price = hist['Close'].iloc[0]
                end_price = hist['Close'].iloc[-1]
                return ((end_price - start_price) / start_price) * 100
            else:
                print(f"Warning: Insufficient data for S&P 500 from {start_str} to {end_str}")
                return 0.0

        except Exception as e:
            print(f"Attempt {attempt + 1} failed for market data: {str(e)}")
            if attempt < max_retries - 1:
                time.sleep(2)  # Wait before retry
            else:
                print(f"Failed to fetch market data after {max_retries} attempts")
                return 0.0

def get_stock_returns(tickers, period_start, period_end, handle_gral=False):
    """
    Get stock returns for given tickers and period with improved error handling
    """
    returns = []

    # Convert dates to string format
    start_str = period_start.strftime('%Y-%m-%d')
    end_str = (period_end + timedelta(days=1)).strftime('%Y-%m-%d')

    for ticker in tickers:
        try:
            # Handle GRAL separately - only go back 3 quarters max
            if ticker == 'GRAL' and handle_gral:
                today = datetime.now()
                three_quarters_ago = today - timedelta(days=270)  # ~9 months
                if period_start < three_quarters_ago:
                    print(f"Skipping {ticker} - date range too far back")
                    returns.append(0.0)
                    continue

            # Create ticker object and get history
            stock_ticker = yf.Ticker(ticker)
            hist = stock_ticker.history(start=start_str, end=end_str, auto_adjust=True)

            if not hist.empty and len(hist) >= 2:
                # Calculate return using Close prices
                start_price = hist['Close'].iloc[0]
                end_price = hist['Close'].iloc[-1]
                stock_return = ((end_price - start_price) / start_price) * 100
                returns.append(stock_return)
                print(f"Successfully fetched {ticker}: {stock_return:.2f}%")
            else:
                print(f"Warning: Insufficient data for {ticker}")
                returns.append(0.0)

        except Exception as e:
            print(f"Error fetching {ticker}: {str(e)}")
            returns.append(0.0)
            time.sleep(0.5)  # Small delay to avoid rate limiting

    return np.array(returns)

def calculate_individual_stock_alpha():
    """
    Calculate alpha for individual stocks over 1Y, 2Y, and 3Y periods
    """
    # Stock tickers
    tickers = ['META', 'REGN', 'FI', 'GILD', 'MITK', 'FIS', 'IDCC', 'COUR', 'AMAT', 'KLAC',
               'NICE', 'WFC', 'AMD', 'LLY', 'NVO', 'DELL', 'BP', 'NOK', 'RMBS', 'EL',
               'UIS', 'ILMN', 'GOOG', 'SNPS', 'GRAL', 'UNH', 'GNRC', 'TXN', 'ROK']

    # Define time periods
    today = datetime.now()

    # Make sure we're not trying to fetch future data
    if today.weekday() >= 5:  # Weekend
        # Use last Friday
        days_back = today.weekday() - 4
        analysis_date = today - timedelta(days=days_back)
    else:
        analysis_date = today

    # Define periods
    one_year_start = analysis_date - timedelta(days=365)
    two_year_start = analysis_date - timedelta(days=730)
    three_year_start = analysis_date - timedelta(days=1095)

    # Display periods
    print(f"Analysis date: {analysis_date.strftime('%Y-%m-%d')}")
    print(f"1Y period: {one_year_start.strftime('%Y-%m-%d')} to {analysis_date.strftime('%Y-%m-%d')}")
    print(f"2Y period: {two_year_start.strftime('%Y-%m-%d')} to {analysis_date.strftime('%Y-%m-%d')}")
    print(f"3Y period: {three_year_start.strftime('%Y-%m-%d')} to {analysis_date.strftime('%Y-%m-%d')}")

    # Initialize return arrays
    returns_1y = np.zeros(len(tickers))
    returns_2y = np.zeros(len(tickers))
    returns_3y = np.zeros(len(tickers))

    # Fetch data in batches to avoid overwhelming the API
    print("\nFetching individual stock data...")

    # 1Y returns
    print("\nFetching 1Y returns...")
    returns_1y = get_stock_returns(tickers, one_year_start, analysis_date, handle_gral=True)

    # 2Y returns
    print("\nFetching 2Y returns...")
    returns_2y = get_stock_returns(tickers, two_year_start, analysis_date, handle_gral=True)

    # 3Y returns
    print("\nFetching 3Y returns...")
    returns_3y = get_stock_returns(tickers, three_year_start, analysis_date, handle_gral=True)

    # Get market returns
    print("\nFetching market data...")
    market_1y = get_market_return(one_year_start, analysis_date)
    market_2y = get_market_return(two_year_start, analysis_date)
    market_3y = get_market_return(three_year_start, analysis_date)

    print(f"\nMarket returns: 1Y={market_1y:.2f}%, 2Y={market_2y:.2f}%, 3Y={market_3y:.2f}%")

    # Risk-free rates (3-month T-bill = 4.42%)
    risk_free_1y = 4.42
    risk_free_2y = 4.42 * 2  # 2Y cumulative
    risk_free_3y = 4.42 * 3  # 3Y cumulative

    # Calculate alpha for each stock
    alphas_1y = []
    alphas_2y = []
    alphas_3y = []

    for i in range(len(tickers)):
        # 1Y Alpha
        alpha_1y = (returns_1y[i] - risk_free_1y) - (market_1y - risk_free_1y)
        alphas_1y.append(alpha_1y)

        # 2Y Alpha
        alpha_2y = (returns_2y[i] - risk_free_2y) - (market_2y - risk_free_2y)
        alphas_2y.append(alpha_2y)

        # 3Y Alpha
        alpha_3y = (returns_3y[i] - risk_free_3y) - (market_3y - risk_free_3y)
        alphas_3y.append(alpha_3y)

    # Create DataFrame
    df_comprehensive = pd.DataFrame({
        'Stock': tickers,
        '1Y_Return': returns_1y,
        '2Y_Return': returns_2y,
        '3Y_Return': returns_3y,
        '1Y_Alpha': alphas_1y,
        '2Y_Alpha': alphas_2y,
        '3Y_Alpha': alphas_3y
    })

    # Sort by alpha
    df_sorted_1y = df_comprehensive.sort_values('1Y_Alpha', ascending=False)
    df_sorted_2y = df_comprehensive.sort_values('2Y_Alpha', ascending=False)
    df_sorted_3y = df_comprehensive.sort_values('3Y_Alpha', ascending=False)

    # Save to CSV
    df_comprehensive.to_csv('alpha_comprehensive_analysis.csv', index=False)
    df_sorted_1y.to_csv('alpha_sorted_by_1y.csv', index=False)
    df_sorted_2y.to_csv('alpha_sorted_by_2y.csv', index=False)
    df_sorted_3y.to_csv('alpha_sorted_by_3y.csv', index=False)

    return df_comprehensive, df_sorted_1y, df_sorted_2y, df_sorted_3y

def calculate_quarterly_portfolio_alpha():
    """
    Calculate portfolio alpha for the last 8 quarters
    """
    # Stock tickers
    tickers = ['META', 'REGN', 'FI', 'GILD', 'MITK', 'FIS', 'IDCC', 'COUR', 'AMAT', 'KLAC',
               'NICE', 'WFC', 'AMD', 'LLY', 'NVO', 'DELL', 'BP', 'NOK', 'RMBS', 'EL',
               'UIS', 'ILMN', 'GOOG', 'SNPS', 'GRAL', 'UNH', 'GNRC', 'TXN', 'ROK']

    # Portfolio weights
    weights = np.array([13.9407, 9.7876, 7.4736, 6.0693, 6.0428, 5.7082, 5.6708, 4.9494,
                       3.7019, 3.5918, 3.2948, 3.0735, 2.9403, 2.7125, 2.6726, 2.4349,
                       2.0997, 2.0104, 1.7872, 1.7506, 1.7250, 1.7083, 1.4630, 1.2205,
                       0.8973, 0.6003, 0.5892, 0.0836, 0.0000]) / 100

    # Build list of quarters
    quarters = []
    quarterly_returns = []
    market_returns = []

    today = datetime.now()

    # Define specific quarters to fetch
    quarter_dates = [
        ('Q2_2025', datetime(2025, 4, 1), datetime(2025, 6, 30)),
        ('Q1_2025', datetime(2025, 1, 1), datetime(2025, 3, 31)),
        ('Q4_2024', datetime(2024, 10, 1), datetime(2024, 12, 31)),
        ('Q3_2024', datetime(2024, 7, 1), datetime(2024, 9, 30)),
        ('Q2_2024', datetime(2024, 4, 1), datetime(2024, 6, 30)),
        ('Q1_2024', datetime(2024, 1, 1), datetime(2024, 3, 31)),
        ('Q4_2023', datetime(2023, 10, 1), datetime(2023, 12, 31)),
        ('Q3_2023', datetime(2023, 7, 1), datetime(2023, 9, 30))
    ]

    # Only include complete quarters
    valid_quarters = []
    for quarter_name, start_date, end_date in quarter_dates:
        if end_date < today:
            valid_quarters.append((quarter_name, start_date, end_date))

    print(f"\nFetching quarterly data for {len(valid_quarters)} quarters...")

    for quarter_name, start_date, end_date in valid_quarters:
        print(f"\nProcessing {quarter_name}...")

        # Get stock returns
        quarter_stock_returns = get_stock_returns(tickers, start_date, end_date, handle_gral=True)

        # Get market return
        quarter_market_return = get_market_return(start_date, end_date)

        quarters.append(quarter_name)
        quarterly_returns.append(quarter_stock_returns)
        market_returns.append(quarter_market_return)

    # Calculate portfolio metrics
    portfolio_alphas = []
    portfolio_returns = []
    risk_free_rate = 4.42 / 4  # Quarterly risk-free rate

    for i in range(len(quarters)):
        # Portfolio return
        portfolio_return = np.sum(weights * quarterly_returns[i])

        # Portfolio alpha
        portfolio_alpha = (portfolio_return - risk_free_rate) - (market_returns[i] - risk_free_rate)

        portfolio_returns.append(portfolio_return)
        portfolio_alphas.append(portfolio_alpha)

    # Create DataFrame
    df_quarterly = pd.DataFrame({
        'Quarter': quarters,
        'Portfolio_Return': portfolio_returns,
        'Market_Return': market_returns,
        'Portfolio_Alpha': portfolio_alphas
    })

    # Calculate rolling averages
    df_quarterly['Rolling_4Q_Alpha'] = df_quarterly['Portfolio_Alpha'].rolling(window=4, min_periods=1).mean()
    df_quarterly['Rolling_2Q_Alpha'] = df_quarterly['Portfolio_Alpha'].rolling(window=2, min_periods=1).mean()

    # Save to CSV
    df_quarterly.to_csv('quarterly_portfolio_alpha.csv', index=False)

    return df_quarterly

def calculate_ytd_portfolio_alpha():
    """
    Calculate YTD portfolio alpha
    """
    # Stock tickers and weights
    tickers = ['META', 'REGN', 'FI', 'GILD', 'MITK', 'FIS', 'IDCC', 'COUR', 'AMAT', 'KLAC',
               'NICE', 'WFC', 'AMD', 'LLY', 'NVO', 'DELL', 'BP', 'NOK', 'RMBS', 'EL',
               'UIS', 'ILMN', 'GOOG', 'SNPS', 'GRAL', 'UNH', 'GNRC', 'TXN', 'ROK']

    weights = np.array([13.9407, 9.7876, 7.4736, 6.0693, 6.0428, 5.7082, 5.6708, 4.9494,
                       3.7019, 3.5918, 3.2948, 3.0735, 2.9403, 2.7125, 2.6726, 2.4349,
                       2.0997, 2.0104, 1.7872, 1.7506, 1.7250, 1.7083, 1.4630, 1.2205,
                       0.8973, 0.6003, 0.5892, 0.0836, 0.0000]) / 100

    # YTD period
    today = datetime.now()
    ytd_start = datetime(today.year, 1, 1)

    print(f"\nCalculating YTD performance ({ytd_start.strftime('%Y-%m-%d')} to {today.strftime('%Y-%m-%d')})...")

    # Get returns
    ytd_returns = get_stock_returns(tickers, ytd_start, today, handle_gral=True)
    market_ytd = get_market_return(ytd_start, today)

    # Calculate portfolio return
    portfolio_ytd = np.sum(weights * ytd_returns)

    # Risk-free rate (prorated for YTD)
    days_elapsed = (today - ytd_start).days
    risk_free_ytd = 4.42 * (days_elapsed / 365)

    # Calculate alpha
    portfolio_alpha_ytd = (portfolio_ytd - risk_free_ytd) - (market_ytd - risk_free_ytd)

    print(f"\nYTD Performance Summary:")
    print(f"Portfolio Return: {portfolio_ytd:.2f}%")
    print(f"Market Return: {market_ytd:.2f}%")
    print(f"Portfolio Alpha: {portfolio_alpha_ytd:.2f}%")

    return portfolio_alpha_ytd, portfolio_ytd, market_ytd

def test_connection():
    """
    Test if we can fetch data from yfinance
    """
    print("Testing yfinance connection...")
    try:
        test_ticker = yf.Ticker("SPY")
        hist = test_ticker.history(period="1d")
        if not hist.empty:
            print("✓ Connection successful")
            return True
        else:
            print("✗ No data received")
            return False
    except Exception as e:
        print(f"✗ Connection failed: {str(e)}")
        return False

if __name__ == "__main__":
    print("Portfolio Alpha Analysis with yFinance")
    print("=" * 70)

    # Test connection first
    if not test_connection():
        print("\nWarning: Unable to connect to yfinance. Results may be limited.")
        print("Continuing with analysis...\n")

    try:
        # Individual stock analysis
        print("\n" + "=" * 70)
        print("INDIVIDUAL STOCK ALPHA ANALYSIS")
        print("=" * 70)

        df_comprehensive, df_sorted_1y, df_sorted_2y, df_sorted_3y = calculate_individual_stock_alpha()

        # Display results
        print("\nTop 10 Stocks by 1Y Alpha:")
        print(df_sorted_1y.head(10)[['Stock', '1Y_Return', '1Y_Alpha']].to_string(index=False, float_format='%.2f'))

        print("\nBottom 5 Stocks by 1Y Alpha:")
        print(df_sorted_1y.tail(5)[['Stock', '1Y_Return', '1Y_Alpha']].to_string(index=False, float_format='%.2f'))

        # Portfolio analysis
        print("\n" + "=" * 70)
        print("PORTFOLIO ALPHA ANALYSIS")
        print("=" * 70)

        # YTD analysis
        ytd_alpha, ytd_return, ytd_market = calculate_ytd_portfolio_alpha()

        # Quarterly analysis
        print("\n" + "=" * 70)
        print("QUARTERLY PORTFOLIO ALPHA")
        print("=" * 70)

        quarterly_df = calculate_quarterly_portfolio_alpha()

        if not quarterly_df.empty:
            print("\nQuarterly Performance:")
            print(quarterly_df.to_string(index=False, float_format='%.2f'))

            # Summary statistics
            print("\n" + "=" * 70)
            print("SUMMARY STATISTICS")
            print("=" * 70)

            if len(quarterly_df) >= 4:
                print(f"Trailing 4-Quarter Average Alpha: {quarterly_df['Rolling_4Q_Alpha'].iloc[-1]:.2f}%")
            if len(quarterly_df) >= 2:
                print(f"Trailing 2-Quarter Average Alpha: {quarterly_df['Rolling_2Q_Alpha'].iloc[-1]:.2f}%")

            print(f"Latest Quarter Alpha: {quarterly_df['Portfolio_Alpha'].iloc[-1]:.2f}%")

        # Save summary report
        summary_data = {
            'Metric': ['YTD Portfolio Return', 'YTD Market Return', 'YTD Portfolio Alpha',
                      'Latest Quarter Alpha', '4Q Rolling Alpha', '2Q Rolling Alpha'],
            'Value': [ytd_return, ytd_market, ytd_alpha,
                     quarterly_df['Portfolio_Alpha'].iloc[-1] if not quarterly_df.empty else 0,
                     quarterly_df['Rolling_4Q_Alpha'].iloc[-1] if len(quarterly_df) >= 4 else 0,
                     quarterly_df['Rolling_2Q_Alpha'].iloc[-1] if len(quarterly_df) >= 2 else 0]
        }

        summary_df = pd.DataFrame(summary_data)
        summary_df.to_csv('portfolio_summary.csv', index=False)

        print("\n" + "=" * 70)
        print("Analysis complete! CSV files saved.")
        print("Files created:")
        print("- alpha_comprehensive_analysis.csv")
        print("- alpha_sorted_by_1y.csv")
        print("- alpha_sorted_by_2y.csv")
        print("- alpha_sorted_by_3y.csv")
        print("- quarterly_portfolio_alpha.csv")
        print("- portfolio_summary.csv")

    except Exception as e:
        print(f"\nError during analysis: {str(e)}")
        print("Please check your internet connection and try again.")
# Out:
# Portfolio Alpha Analysis with yFinance
# ======================================================================
# Testing yfinance connection...
# ✓ Connection successful
#
# ======================================================================
# INDIVIDUAL STOCK ALPHA ANALYSIS
# ======================================================================
# Analysis date: 2025-07-09
# 1Y period: 2024-07-09 to 2025-07-09
# 2Y period: 2023-07-10 to 2025-07-09
# 3Y period: 2022-07-10 to 2025-07-09
#
# Fetching individual stock data...
#
# Fetching 1Y returns...
# Successfully fetched META: 39.09%
# Successfully fetched REGN: -48.01%
# Successfully fetched FI: 12.52%
# Successfully fetched GILD: 71.70%
# Successfully fetched MITK: -6.99%
# Successfully fetched FIS: 10.29%
# Successfully fetched IDCC: 89.10%
# Successfully fetched COUR: 20.46%
# Successfully fetched AMAT: -21.70%
# Successfully fetched KLAC: 5.99%
# Successfully fetched NICE: -0.51%
# Successfully fetched WFC: 39.97%
# Successfully fetched AMD: -21.93%
# Successfully fetched LLY: -15.05%
# Successfully fetched NVO: -49.59%
# Successfully fetched DELL: -12.57%
# Successfully fetched BP: -4.36%
# Successfully fetched NOK: 35.41%
# Successfully fetched RMBS: 1.03%
# Successfully fetched EL: -15.75%
# Successfully fetched UIS: 0.00%
# Successfully fetched ILMN: -10.39%
# Successfully fetched GOOG: -5.55%
# Successfully fetched SNPS: -10.24%
# Skipping GRAL - date range too far back
# Successfully fetched UNH: -37.84%
# Successfully fetched GNRC: 4.68%
# Successfully fetched TXN: 11.02%
# Successfully fetched ROK: 31.83%
#
# Fetching 2Y returns...
# Successfully fetched META: 151.25%
# Successfully fetched REGN: -22.09%
# Successfully fetched FI: 33.96%
# Successfully fetched GILD: 60.11%
# Successfully fetched MITK: -8.51%
# Successfully fetched FIS: 43.26%
# Successfully fetched IDCC: 144.67%
# Successfully fetched COUR: -34.62%
# Successfully fetched AMAT: 41.19%
# Successfully fetched KLAC: 100.23%
# Successfully fetched NICE: -14.98%
# Successfully fetched WFC: 103.92%
# Successfully fetched AMD: 21.70%
# Successfully fetched LLY: 76.11%
# Successfully fetched NVO: -8.76%
# Successfully fetched DELL: 137.12%
# Successfully fetched BP: -0.80%
# Successfully fetched NOK: 30.42%
# Successfully fetched RMBS: 4.84%
# Successfully fetched EL: -53.66%
# Successfully fetched UIS: 5.62%
# Successfully fetched ILMN: -46.58%
# Successfully fetched GOOG: 53.99%
# Successfully fetched SNPS: 22.43%
# Skipping GRAL - date range too far back
# Successfully fetched UNH: -32.93%
# Successfully fetched GNRC: 5.97%
# Successfully fetched TXN: 27.75%
# Successfully fetched ROK: 4.43%
#
# Fetching 3Y returns...
# Successfully fetched META: 353.62%
# Successfully fetched REGN: -10.82%
# Successfully fetched FI: 83.56%
# Successfully fetched GILD: 101.00%
# Successfully fetched MITK: 8.36%
# Successfully fetched FIS: -8.30%
# Successfully fetched IDCC: 281.40%
# Successfully fetched COUR: -44.53%
# Successfully fetched AMAT: 126.14%
# Successfully fetched KLAC: 203.07%
# Successfully fetched NICE: -14.37%
# Successfully fetched WFC: 122.90%
# Successfully fetched AMD: 79.64%
# Successfully fetched LLY: 143.63%
# Successfully fetched NVO: 32.59%
# Successfully fetched DELL: 216.89%
# Successfully fetched BP: 32.80%
# Successfully fetched NOK: 20.03%
# Successfully fetched RMBS: 205.30%
# Successfully fetched EL: -63.12%
# Successfully fetched UIS: -65.47%
# Successfully fetched ILMN: -48.37%
# Successfully fetched GOOG: 54.47%
# Successfully fetched SNPS: 73.10%
# Skipping GRAL - date range too far back
# Successfully fetched UNH: -39.08%
# Successfully fetched GNRC: -32.90%
# Successfully fetched TXN: 53.71%
# Successfully fetched ROK: 77.65%
#
# Fetching market data...
#
# Market returns: 1Y=11.94%, 2Y=41.58%, 3Y=61.97%
#
# Top 10 Stocks by 1Y Alpha:
# Stock  1Y_Return  1Y_Alpha
#  IDCC      89.10     77.16
#  GILD      71.70     59.76
#   WFC      39.97     28.03
#  META      39.09     27.14
#   NOK      35.41     23.47
#   ROK      31.83     19.89
#  COUR      20.46      8.52
#    FI      12.52      0.57
#   TXN      11.02     -0.92
#   FIS      10.29     -1.65
#
# Bottom 5 Stocks by 1Y Alpha:
# Stock  1Y_Return  1Y_Alpha
#  AMAT     -21.70    -33.64
#   AMD     -21.93    -33.87
#   UNH     -37.84    -49.78
#  REGN     -48.01    -59.95
#   NVO     -49.59    -61.53
#
# ======================================================================
# PORTFOLIO ALPHA ANALYSIS
# ======================================================================
#
# Calculating YTD performance (2025-01-01 to 2025-07-09)...
# Successfully fetched META: 22.83%
# Successfully fetched REGN: -23.38%
# Successfully fetched FI: -17.49%
# Successfully fetched GILD: 24.34%
# Successfully fetched MITK: -7.08%
# Successfully fetched FIS: 0.64%
# Successfully fetched IDCC: 16.19%
# Successfully fetched COUR: 1.00%
# Successfully fetched AMAT: 19.63%
# Successfully fetched KLAC: 45.00%
# Successfully fetched NICE: 1.31%
# Successfully fetched WFC: 17.79%
# Successfully fetched AMD: 14.59%
# Successfully fetched LLY: 1.37%
# Successfully fetched NVO: -19.40%
# Successfully fetched DELL: 8.58%
# Successfully fetched BP: 7.88%
# Successfully fetched NOK: 15.38%
# Successfully fetched RMBS: 20.64%
# Successfully fetched EL: 17.29%
# Successfully fetched UIS: -33.23%
# Successfully fetched ILMN: -26.99%
# Successfully fetched GOOG: -5.92%
# Successfully fetched SNPS: 13.02%
# Successfully fetched GRAL: 139.96%
# Successfully fetched UNH: -39.83%
# Successfully fetched GNRC: -4.76%
# Successfully fetched TXN: 17.31%
# Successfully fetched ROK: 21.46%
#
# YTD Performance Summary:
# Portfolio Return: 5.92%
# Market Return: 6.38%
# Portfolio Alpha: -0.46%
#
# ======================================================================
# QUARTERLY PORTFOLIO ALPHA
# ======================================================================
#
# Fetching quarterly data for 8 quarters...
#
# Processing Q2_2025...
# Successfully fetched META: 26.05%
# Successfully fetched REGN: -14.79%
# Successfully fetched FI: -22.34%
# Successfully fetched GILD: 0.34%
# Successfully fetched MITK: 18.71%
# Successfully fetched FIS: 9.71%
# Successfully fetched IDCC: 9.76%
# Successfully fetched COUR: 29.59%
# Successfully fetched AMAT: 26.04%
# Successfully fetched KLAC: 31.57%
# Successfully fetched NICE: 8.91%
# Successfully fetched WFC: 12.97%
# Successfully fetched AMD: 38.06%
# Successfully fetched LLY: -2.99%
# Successfully fetched NVO: 1.46%
# Successfully fetched DELL: 34.17%
# Successfully fetched BP: -10.04%
# Successfully fetched NOK: -2.11%
# Successfully fetched RMBS: 22.43%
# Successfully fetched EL: 19.66%
# Successfully fetched UIS: 0.22%
# Successfully fetched ILMN: 21.71%
# Successfully fetched GOOG: 11.78%
# Successfully fetched SNPS: 17.60%
# Successfully fetched GRAL: 104.86%
# Successfully fetched UNH: -39.94%
# Successfully fetched GNRC: 13.36%
# Successfully fetched TXN: 17.64%
# Successfully fetched ROK: 28.93%
#
# Processing Q1_2025...
# Successfully fetched META: -3.73%
# Successfully fetched REGN: -11.21%
# Successfully fetched FI: 7.21%
# Successfully fetched GILD: 22.81%
# Successfully fetched MITK: -24.17%
# Successfully fetched FIS: -6.23%
# Successfully fetched IDCC: 5.70%
# Successfully fetched COUR: -21.46%
# Successfully fetched AMAT: -11.24%
# Successfully fetched KLAC: 7.02%
# Successfully fetched NICE: -9.11%
# Successfully fetched WFC: 2.78%
# Successfully fetched AMD: -14.83%
# Successfully fetched LLY: 6.33%
# Successfully fetched NVO: -19.38%
# Successfully fetched DELL: -21.47%
# Successfully fetched BP: 14.48%
# Successfully fetched NOK: 18.96%
# Successfully fetched RMBS: -3.21%
# Successfully fetched EL: -10.36%
# Successfully fetched UIS: -29.06%
# Successfully fetched ILMN: -39.40%
# Successfully fetched GOOG: -17.95%
# Successfully fetched SNPS: -11.17%
# Successfully fetched GRAL: 42.52%
# Successfully fetched UNH: 4.26%
# Successfully fetched GNRC: -19.33%
# Successfully fetched TXN: -3.17%
# Successfully fetched ROK: -7.60%
#
# Processing Q4_2024...
# Successfully fetched META: 1.65%
# Successfully fetched REGN: -31.96%
# Successfully fetched FI: 13.30%
# Successfully fetched GILD: 10.97%
# Successfully fetched MITK: 31.25%
# Successfully fetched FIS: -3.06%
# Successfully fetched IDCC: 36.21%
# Successfully fetched COUR: 11.84%
# Successfully fetched AMAT: -17.34%
# Successfully fetched KLAC: -16.16%
# Successfully fetched NICE: 3.11%
# Successfully fetched WFC: 27.54%
# Successfully fetched AMD: -24.39%
# Successfully fetched LLY: -12.57%
# Successfully fetched NVO: -27.11%
# Successfully fetched DELL: 2.20%
# Successfully fetched BP: -6.40%
# Successfully fetched NOK: 2.52%
# Successfully fetched RMBS: 31.72%
# Successfully fetched EL: -22.53%
# Successfully fetched UIS: 14.05%
# Successfully fetched ILMN: 3.61%
# Successfully fetched GOOG: 13.20%
# Successfully fetched SNPS: -2.06%
# Skipping GRAL - date range too far back
# Successfully fetched UNH: -12.94%
# Successfully fetched GNRC: -1.97%
# Successfully fetched TXN: -6.38%
# Successfully fetched ROK: 8.24%
#
# Processing Q3_2024...
# Successfully fetched META: 13.53%
# Successfully fetched REGN: -0.55%
# Successfully fetched FI: 22.09%
# Successfully fetched GILD: 23.29%
# Successfully fetched MITK: -21.96%
# Successfully fetched FIS: 13.26%
# Successfully fetched IDCC: 22.20%
# Successfully fetched COUR: 12.31%
# Successfully fetched AMAT: -14.73%
# Successfully fetched KLAC: -6.28%
# Successfully fetched NICE: 3.01%
# Successfully fetched WFC: -6.05%
# Successfully fetched AMD: 4.05%
# Successfully fetched LLY: -2.97%
# Successfully fetched NVO: -17.81%
# Successfully fetched DELL: -16.71%
# Successfully fetched BP: -12.58%
# Successfully fetched NOK: 13.34%
# Successfully fetched RMBS: -27.21%
# Successfully fetched EL: -4.71%
# Successfully fetched UIS: 37.20%
# Successfully fetched ILMN: 23.61%
# Successfully fetched GOOG: -9.26%
# Successfully fetched SNPS: -15.85%
# Skipping GRAL - date range too far back
# Successfully fetched UNH: 18.62%
# Successfully fetched GNRC: 19.32%
# Successfully fetched TXN: 6.84%
# Successfully fetched ROK: 1.60%
#
# Processing Q2_2024...
# Successfully fetched META: 2.72%
# Successfully fetched REGN: 8.43%
# Successfully fetched FI: -6.01%
# Successfully fetched GILD: -4.70%
# Successfully fetched MITK: -22.31%
# Successfully fetched FIS: 4.07%
# Successfully fetched IDCC: 20.23%
# Successfully fetched COUR: -48.49%
# Successfully fetched AMAT: 13.29%
# Successfully fetched KLAC: 16.22%
# Successfully fetched NICE: -32.46%
# Successfully fetched WFC: 3.68%
# Successfully fetched AMD: -11.53%
# Successfully fetched LLY: 19.25%
# Successfully fetched NVO: 11.91%
# Successfully fetched DELL: 15.72%
# Successfully fetched BP: -3.74%
# Successfully fetched NOK: 9.34%
# Successfully fetched RMBS: -5.58%
# Successfully fetched EL: -29.63%
# Successfully fetched UIS: -23.94%
# Successfully fetched ILMN: -19.15%
# Successfully fetched GOOG: 17.33%
# Successfully fetched SNPS: 3.15%
# Skipping GRAL - date range too far back
# Successfully fetched UNH: 4.44%
# Successfully fetched GNRC: 3.78%
# Successfully fetched TXN: 13.14%
# Successfully fetched ROK: -2.40%
#
# Processing Q1_2024...
# Successfully fetched META: 40.37%
# Successfully fetched REGN: 6.35%
# Successfully fetched FI: 20.09%
# Successfully fetched GILD: -11.10%
# Successfully fetched MITK: 9.39%
# Successfully fetched FIS: 22.30%
# Successfully fetched IDCC: 0.57%
# Successfully fetched COUR: -27.32%
# Successfully fetched AMAT: 33.82%
# Successfully fetched KLAC: 24.93%
# Successfully fetched NICE: 35.20%
# Successfully fetched WFC: 18.32%
# Successfully fetched AMD: 30.24%
# Successfully fetched LLY: 31.60%
# Successfully fetched NVO: 26.65%
# Successfully fetched DELL: 53.26%
# Successfully fetched BP: 7.45%
# Successfully fetched NOK: 4.72%
# Successfully fetched RMBS: -5.27%
# Successfully fetched EL: 6.45%
# Successfully fetched UIS: -13.86%
# Successfully fetched ILMN: -0.21%
# Successfully fetched GOOG: 9.10%
# Successfully fetched SNPS: 14.54%
# Skipping GRAL - date range too far back
# Successfully fetched UNH: -7.92%
# Successfully fetched GNRC: -0.97%
# Successfully fetched TXN: 3.74%
# Successfully fetched ROK: -4.49%
#
# Processing Q4_2023...
# Successfully fetched META: 15.36%
# Successfully fetched REGN: 7.37%
# Successfully fetched FI: 17.71%
# Successfully fetched GILD: 10.32%
# Successfully fetched MITK: 23.48%
# Successfully fetched FIS: 11.73%
# Successfully fetched IDCC: 35.65%
# Successfully fetched COUR: 5.33%
# Successfully fetched AMAT: 16.42%
# Successfully fetched KLAC: 26.54%
# Successfully fetched NICE: 15.49%
# Successfully fetched WFC: 25.37%
# Successfully fetched AMD: 42.74%
# Successfully fetched LLY: 8.49%
# Successfully fetched NVO: 12.69%
# Successfully fetched DELL: 13.64%
# Successfully fetched BP: -5.21%
# Successfully fetched NOK: -7.13%
# Successfully fetched RMBS: 21.51%
# Successfully fetched EL: 2.52%
# Successfully fetched UIS: 56.55%
# Successfully fetched ILMN: 2.05%
# Successfully fetched GOOG: 4.26%
# Successfully fetched SNPS: 11.02%
# Skipping GRAL - date range too far back
# Successfully fetched UNH: 2.66%
# Successfully fetched GNRC: 21.81%
# Successfully fetched TXN: 7.55%
# Successfully fetched ROK: 9.88%
#
# Processing Q3_2023...
# Successfully fetched META: 4.96%
# Successfully fetched REGN: 14.60%
# Successfully fetched FI: -10.31%
# Successfully fetched GILD: -1.36%
# Successfully fetched MITK: -4.54%
# Successfully fetched FIS: -3.80%
# Successfully fetched IDCC: -16.19%
# Successfully fetched COUR: 43.44%
# Successfully fetched AMAT: -4.62%
# Successfully fetched KLAC: -5.14%
# Successfully fetched NICE: -15.85%
# Successfully fetched WFC: -5.12%
# Successfully fetched AMD: -11.22%
# Successfully fetched LLY: 16.66%
# Successfully fetched NVO: 14.63%
# Successfully fetched DELL: 27.05%
# Successfully fetched BP: 9.04%
# Successfully fetched NOK: -11.02%
# Successfully fetched RMBS: -12.72%
# Successfully fetched EL: -26.69%
# Successfully fetched UIS: -14.60%
# Successfully fetched ILMN: -27.03%
# Successfully fetched GOOG: 9.36%
# Successfully fetched SNPS: 5.75%
# Skipping GRAL - date range too far back
# Successfully fetched UNH: 5.92%
# Successfully fetched GNRC: -27.65%
# Successfully fetched TXN: -10.92%
# Successfully fetched ROK: -12.89%
#
# Quarterly Performance:
# Quarter  Portfolio_Return  Market_Return  Portfolio_Alpha  Rolling_4Q_Alpha  Rolling_2Q_Alpha
# Q2_2025             10.99          10.15             0.83              0.83              0.83
# Q1_2025             -4.77          -4.37            -0.39              0.22              0.22
# Q4_2024              1.58           3.03            -1.45             -0.34             -0.92
# Q3_2024              4.88           5.25            -0.37             -0.35             -0.91
# Q2_2024             -1.79           4.13            -5.93             -2.04             -3.15
# Q1_2024             15.51          10.79             4.73             -0.76             -0.60
# Q4_2023             15.73          11.23             4.50              0.73              4.62
# Q3_2023              0.77          -3.76             4.54              1.96              4.52
#
# ======================================================================
# SUMMARY STATISTICS
# ======================================================================
# Trailing 4-Quarter Average Alpha: 1.96%
# Trailing 2-Quarter Average Alpha: 4.52%
# Latest Quarter Alpha: 4.54%
#
# ======================================================================
# Analysis complete! CSV files saved.
# Files created:
# - alpha_comprehensive_analysis.csv
# - alpha_sorted_by_1y.csv
# - alpha_sorted_by_2y.csv
# - alpha_sorted_by_3y.csv
# - quarterly_portfolio_alpha.csv
# - portfolio_summary.csv
